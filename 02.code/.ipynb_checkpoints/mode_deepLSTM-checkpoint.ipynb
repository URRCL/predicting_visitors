# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense, LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
# Out:
# Using TensorFlow backend.

# %%
dataframe = pd.read_csv('../01.data/PeopleCountData_wide.txt',sep='|')

# %%
dataframe.head(2)
# Out:
#          date  hour  incoming_DouglassBridge  incoming_FriedlanderLobby  \
# 0  2017-05-04    15                     11.0                       28.0
# 1  2017-05-04    16                     60.0                      256.0
#
#    incoming_GleasonEntrance  incoming_GleasonStacks  outgoing_DouglassBridge  \
# 0                       6.0                     3.0                     11.0
# 1                      83.0                    63.0                     88.0
#
#    outgoing_FriedlanderLobby  outgoing_GleasonEntrance  outgoing_GleasonStacks
# 0                       29.0                      11.0                    16.0
# 1                      241.0                      79.0                    93.0

# %% [markdown]
# ## LSTM Network for Regression

# %%
# fix random seed for reproducibility
np.random.seed(7)

# load the dataset
dataframe_grouped = dataframe.groupby('date').sum().iloc[:-4,1:]
dataframe_grouped['weekday'] = pd.to_datetime(dataframe_grouped.index).weekday

mu = dataframe_grouped[(dataframe_grouped<4000)].mean(0)['outgoing_DouglassBridge']
dataframe_grouped.outgoing_DouglassBridge.loc[dataframe_grouped.outgoing_DouglassBridge>4000] = mu

dataset = dataframe_grouped.values
dataset = dataset.astype('float32')
# Out:
# /home/npatil4/.local/lib/python2.7/site-packages/pandas/core/indexing.py:179: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self._setitem_with_indexer(indexer, value)

# %%
# normalize the dataset

scaler = MinMaxScaler(feature_range=(0, 1))
dataset[:,:-1] = scaler.fit_transform(dataset[:,:-1])

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]
train.shape,test.shape
# Out:
# ((170, 9), (84, 9))

# %%
# convert an array of values into a dataset matrix

def create_dataset(dataset_in, look_back=1):
    
    dataX, dataY = [], []
    
    for i in range(len(dataset_in)-look_back-1):
        
        a = dataset_in[i:(i+look_back), :]
        dataX.append(a)
        dataY.append(dataset_in[i + look_back, :-1])
        
    return np.array(dataX), np.array(dataY)

# %%
# reshape into X=t and Y=t+1
look_back = 7
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
run = '03'

# %%
from keras.callbacks import EarlyStopping,ModelCheckpoint

ES = EarlyStopping(patience=20)

MC = ModelCheckpoint(filepath='../05.model/model_'+run+'.h5')

# %%
from keras.layers import Dropout
from keras.optimizers import Adam
from keras import backend as K

batch_size = 1

# create and fit the LSTM network

K.clear_session()
input_shape = ((batch_size,trainX.shape[1],trainX.shape[-1]))
num_classes = trainY.shape[-1]

model = Sequential()

model.add(LSTM(units = 8, batch_input_shape = input_shape, stateful = True, return_sequences = True))

model.add(LSTM(units = 16, batch_input_shape = input_shape, stateful = True, return_sequences = True))

model.add(LSTM(units = 32, batch_input_shape = input_shape, stateful = True, return_sequences = True))

model.add(LSTM(units = 64, batch_input_shape = input_shape, stateful = True))

model.add(Dense(num_classes))

model.compile(loss='mse', optimizer='adam')

# %%
for i in range(150):
    model.fit(trainX, trainY, epochs=1, batch_size=batch_size, verbose=2, shuffle=False)
    model.reset_states()

model.save('../05.model/model_'+run+'.h5')
# Out:
# Epoch 1/1
#  - 9s - loss: 0.0270
# Epoch 1/1
#  - 8s - loss: 0.0341
# Epoch 1/1
#  - 8s - loss: 0.0386
# Epoch 1/1
#  - 8s - loss: 0.0429
# Epoch 1/1
#  - 8s - loss: 0.0476
# Epoch 1/1
#  - 8s - loss: 0.0472
# Epoch 1/1
#  - 8s - loss: 0.0508
# Epoch 1/1
#  - 8s - loss: 0.0470
# Epoch 1/1
#  - 8s - loss: 0.0471
# Epoch 1/1
#  - 8s - loss: 0.0463
# Epoch 1/1
#  - 8s - loss: 0.0515
# Epoch 1/1
#  - 8s - loss: 0.0561
# Epoch 1/1
#  - 8s - loss: 0.0576
# Epoch 1/1
#  - 8s - loss: 0.0569
# Epoch 1/1
#  - 8s - loss: 0.0583
# Epoch 1/1
#  - 8s - loss: 0.0597
# Epoch 1/1
#  - 8s - loss: 0.0590
# Epoch 1/1
#  - 8s - loss: 0.0598
# Epoch 1/1
#  - 8s - loss: 0.0610
# Epoch 1/1
#  - 8s - loss: 0.0566
# Epoch 1/1
#  - 8s - loss: 0.0531
# Epoch 1/1
#  - 8s - loss: 0.0486
# Epoch 1/1
#  - 8s - loss: 0.0407
# Epoch 1/1
#  - 8s - loss: 0.0402
# Epoch 1/1
#  - 8s - loss: 0.0405
# Epoch 1/1
#  - 8s - loss: 0.0407
# Epoch 1/1
#  - 8s - loss: 0.0378
# Epoch 1/1
#  - 8s - loss: 0.0275
# Epoch 1/1
#  - 8s - loss: 0.0293
# Epoch 1/1
#  - 8s - loss: 0.0293
# Epoch 1/1
#  - 8s - loss: 0.0307
# Epoch 1/1
#  - 8s - loss: 0.0269
# Epoch 1/1
#  - 8s - loss: 0.0259
# Epoch 1/1
#  - 8s - loss: 0.0271
# Epoch 1/1
#  - 8s - loss: 0.0257
# Epoch 1/1
#  - 8s - loss: 0.0262
# Epoch 1/1
#  - 8s - loss: 0.0253
# Epoch 1/1
#  - 8s - loss: 0.0252
# Epoch 1/1
#  - 8s - loss: 0.0245
# Epoch 1/1
#  - 8s - loss: 0.0242
# Epoch 1/1
#  - 8s - loss: 0.0219
# Epoch 1/1
#  - 8s - loss: 0.0200
# Epoch 1/1
#  - 8s - loss: 0.0186
# Epoch 1/1
#  - 8s - loss: 0.0170
# Epoch 1/1
#  - 8s - loss: 0.0157
# Epoch 1/1
#  - 8s - loss: 0.0151
# Epoch 1/1
#  - 8s - loss: 0.0139
# Epoch 1/1
#  - 8s - loss: 0.0135
# Epoch 1/1
#  - 8s - loss: 0.0124
# Epoch 1/1
#  - 8s - loss: 0.0121
# Epoch 1/1
#  - 8s - loss: 0.0109
# Epoch 1/1
#  - 8s - loss: 0.0112
# Epoch 1/1
#  - 8s - loss: 0.0110
# Epoch 1/1
#  - 8s - loss: 0.0111
# Epoch 1/1
#  - 8s - loss: 0.0116
# Epoch 1/1
#  - 8s - loss: 0.0106
# Epoch 1/1
#  - 8s - loss: 0.0111
# Epoch 1/1
#  - 8s - loss: 0.0104
# Epoch 1/1
#  - 8s - loss: 0.0108
# Epoch 1/1
#  - 8s - loss: 0.0101
# Epoch 1/1
#  - 8s - loss: 0.0096
# Epoch 1/1
#  - 8s - loss: 0.0102
# Epoch 1/1
#  - 8s - loss: 0.0101
# Epoch 1/1
#  - 8s - loss: 0.0088
# Epoch 1/1
#  - 8s - loss: 0.0092
# Epoch 1/1
#  - 8s - loss: 0.0086
# Epoch 1/1
#  - 8s - loss: 0.0080
# Epoch 1/1
#  - 8s - loss: 0.0077
# Epoch 1/1
#  - 8s - loss: 0.0071
# Epoch 1/1
#  - 8s - loss: 0.0072
# Epoch 1/1
#  - 8s - loss: 0.0069
# Epoch 1/1
#  - 8s - loss: 0.0068
# Epoch 1/1
#  - 8s - loss: 0.0066
# Epoch 1/1
#  - 8s - loss: 0.0067
# Epoch 1/1
#  - 8s - loss: 0.0063
# Epoch 1/1
#  - 8s - loss: 0.0067
# Epoch 1/1
#  - 8s - loss: 0.0064
# Epoch 1/1
#  - 8s - loss: 0.0068
# Epoch 1/1
#  - 8s - loss: 0.0058
# Epoch 1/1
#  - 8s - loss: 0.0058
# Epoch 1/1
#  - 8s - loss: 0.0058
# Epoch 1/1
#  - 8s - loss: 0.0057
# Epoch 1/1
#  - 8s - loss: 0.0060
# Epoch 1/1
#  - 8s - loss: 0.0053
# Epoch 1/1
#  - 8s - loss: 0.0053
# Epoch 1/1
#  - 8s - loss: 0.0052
# Epoch 1/1
#  - 8s - loss: 0.0056
# Epoch 1/1
#  - 8s - loss: 0.0051
# Epoch 1/1
#  - 8s - loss: 0.0050
# Epoch 1/1
#  - 8s - loss: 0.0051
# Epoch 1/1
#  - 8s - loss: 0.0057
# Epoch 1/1
#  - 8s - loss: 0.0054
# Epoch 1/1
#  - 8s - loss: 0.0051
# Epoch 1/1
#  - 8s - loss: 0.0049
# Epoch 1/1
#  - 8s - loss: 0.0049
# Epoch 1/1
#  - 8s - loss: 0.0049
# Epoch 1/1
#  - 8s - loss: 0.0047
# Epoch 1/1
#  - 8s - loss: 0.0047
# Epoch 1/1
#  - 8s - loss: 0.0048
# Epoch 1/1
#  - 8s - loss: 0.0067
# Epoch 1/1
#  - 8s - loss: 0.0057
# Epoch 1/1
#  - 8s - loss: 0.0048
# Epoch 1/1
#  - 8s - loss: 0.0040
# Epoch 1/1
#  - 8s - loss: 0.0037
# Epoch 1/1
#  - 8s - loss: 0.0034
# Epoch 1/1
#  - 8s - loss: 0.0033
# Epoch 1/1
#  - 8s - loss: 0.0038
# Epoch 1/1
#  - 8s - loss: 0.0031
# Epoch 1/1
#  - 8s - loss: 0.0029
# Epoch 1/1
#  - 8s - loss: 0.0028
# Epoch 1/1
#  - 8s - loss: 0.0028
# Epoch 1/1
#  - 8s - loss: 0.0033
# Epoch 1/1
#  - 8s - loss: 0.0031
# Epoch 1/1
#  - 8s - loss: 0.0029
# Epoch 1/1
#  - 8s - loss: 0.0026
# Epoch 1/1
#  - 8s - loss: 0.0033
# Epoch 1/1
#  - 8s - loss: 0.0035
# Epoch 1/1
#  - 8s - loss: 0.0032
# Epoch 1/1
#  - 8s - loss: 0.0041
# Epoch 1/1
#  - 8s - loss: 0.0036
# Epoch 1/1
#  - 8s - loss: 0.0028
# Epoch 1/1
#  - 8s - loss: 0.0039
# Epoch 1/1
#  - 8s - loss: 0.0033
# Epoch 1/1
#  - 8s - loss: 0.0026
# Epoch 1/1
#  - 8s - loss: 0.0024
# Epoch 1/1
#  - 8s - loss: 0.0040
# Epoch 1/1
#  - 8s - loss: 0.0030
# Epoch 1/1
#  - 8s - loss: 0.0024
# Epoch 1/1
#  - 8s - loss: 0.0022
# Epoch 1/1
#  - 8s - loss: 0.0020
# Epoch 1/1
#  - 8s - loss: 0.0020
# Epoch 1/1
#  - 8s - loss: 0.0019
# Epoch 1/1
#  - 8s - loss: 0.0020
# Epoch 1/1
#  - 8s - loss: 0.0018
# Epoch 1/1
#  - 8s - loss: 0.0018
# Epoch 1/1
#  - 8s - loss: 0.0017
# Epoch 1/1
#  - 8s - loss: 0.0033
# Epoch 1/1
#  - 8s - loss: 0.0026
# Epoch 1/1
#  - 8s - loss: 0.0031
# Epoch 1/1
#  - 8s - loss: 0.0023
# Epoch 1/1
#  - 8s - loss: 0.0021
# Epoch 1/1
#  - 8s - loss: 0.0020
# Epoch 1/1
#  - 8s - loss: 0.0019
# Epoch 1/1
#  - 8s - loss: 0.0017
# Epoch 1/1
#  - 8s - loss: 0.0015
# Epoch 1/1
#  - 8s - loss: 0.0015
# Epoch 1/1
#  - 8s - loss: 0.0015
# Epoch 1/1
#  - 8s - loss: 0.0014
# Epoch 1/1
#  - 8s - loss: 0.0015
# Epoch 1/1
#  - 8s - loss: 0.0014

# %%
from keras.models import load_model
model = load_model('../05.model/model_'+run+'.h5')

# make predictions

trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()

testPredict = model.predict(testX, batch_size=batch_size)

# invert predictions

trainPredict = scaler.inverse_transform(trainPredict)
trainY_actual = scaler.inverse_transform(trainY)
testPredict = scaler.inverse_transform(testPredict)
testY_actual = scaler.inverse_transform(testY)


# calculate root mean squared error

trainScore = math.sqrt(mean_squared_error(trainY_actual, trainPredict))
print('Train Score: %.2f RMSE' % (trainScore))
testScore = math.sqrt(mean_squared_error(testY_actual, testPredict))
print('Test Score: %.2f RMSE' % (testScore))
# Out:
# Train Score: 183.75 RMSE
# Test Score: 407.72 RMSE

# %%
# make predictions

trainPredict = model.predict(trainX, batch_size=batch_size)
model.reset_states()

testPredict = model.predict(testX, batch_size=batch_size)

# %%
# plot baseline and predictions

actualPlot = scaler.inverse_transform(dataset[:,:-1])
predictPlot = scaler.inverse_transform(np.concatenate([trainPredict,testPredict]))

plt.figure(figsize=(12,6),dpi=125)
plt.plot(actualPlot, ls='--', lw=0.25)
plt.plot(predictPlot, ls='-', lw=0.25)
plt.vlines(x = trainX.shape[0], ymin=0, ymax=5000, linestyles='dashed')
plt.axis([0,260,0,5000])
plt.grid(ls='--',lw=0.75,alpha=0.75)
plt.text(50,4500,'Training Phase')
plt.text(225,4500,'Test Phase');
